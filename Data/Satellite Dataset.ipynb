# %% [markdown]
# ## 🌐 Dataset Reference
#
# <div align="center">
#
# ### 📦 Research Dataset Available on Zenodo
#
# [![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.15622749.svg)](https://doi.org/10.5281/zenodo.15622749)
#
# **All datasets used in this project are openly available for research purposes.**
#
# | Content | Description |
# | :--- | :--- |
# | 🖼️ High-resolution imagery | Satellite/UAV/field data |
# | 🏷️ Ground truth labels | Manually annotated samples |
# | 📊 Benchmark results | Performance metrics and baselines |
#
# 🔗 Click the badge above to access the dataset on Zenodo.
#
# </div>
